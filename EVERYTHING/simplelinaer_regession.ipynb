# %%
//simple code

# %% [markdown]
# linear regression

# %%
from sklearn.linear_model import LinearRegression
X = [[1],[2],[3],[4],[5],[6],[7],[8],[9]]
y = [40,50,60,70,80,90,95,99]
model = LinearRegression()
model.fit(x,y)
hours = float(input("enter your study hour to calculate your marks"))
predicted_marks = model.predict([[hours]])
print(f"based on ypur study here yourhours {hours} score maybe get ok ?")
