# %% [markdown]
# this model i have bulid that confusion matirx that reduce model data basies , the model : confision matrix

# %%
from sklearn.metrics import confusion_matrix
#data 
y_true = [1,0,1,0,1,0,1]
y_predict = [1,0,0,0,1,1,0]
cm = confusion_matrix(y_true,y_predict)
print("confusion_matrix")
print("cm")
