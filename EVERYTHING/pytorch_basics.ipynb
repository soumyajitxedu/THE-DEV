# %% [markdown]
# // this my frist on pytorch so i want push the baundries so
# i gonna learn the basics then model then ann then idk
# <h1> pytorch :  </h1>
# <h2> basics and tensors </h2>
#
# """
#
# basic of tensors to feature , use and etc
# how its help full
#
# """

# %%
import torch
x = torch.tensor([1,2,3,4,5,67,54]) #its similar to array
print(x)

# %% [markdown]
# ### addidtional concepts and features

# %%
a = torch.zeros([7,2])
print(a)


b = torch.ones(4,7)
print(b)

c = torch.rand(4,9)
print(c)


print(c.shape)
# Out:
# Running cells with '.venv (3.11.9) (Python 3.11.9)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/maina/Downloads/soumyajit drive/pythonlst/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %% [markdown]
# <h2> Tensors : slicing & index with operations</h2>

# %%
a = torch.tensor([[1,218,725],
                  [51,44,243]])
print(a[1,2])
