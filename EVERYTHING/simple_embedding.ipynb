# %%
import torch 
import torch.nn as nn
embedding  = nn.Embedding(10000,128)
word_ids = torch.tensor([2,3,4])
vectors = embedding(word_ids)
batch = torch.tensor([[2,3,4,0],
                      [2,3,7,5]])
vectors = embedding(batch)
print(vectors.shape)
print(vectors)
print(vectors[0][0])
print(embedding.weight[2])
