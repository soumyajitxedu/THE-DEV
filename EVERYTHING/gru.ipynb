# %%
import torch 
import torch.nn as nn

class GRU_classifier(nn.Module):
    def __init__(self,inut_size,hiddeen_size,num_layers,num_classes):
            super().__init__()
            self.hidden_size = hiddeen_size
            self.num_layers = num_layers

            self.gru = nn.GRU(
                input_size = inut_size,
                hidden_size = hiddeen_size,
                num_layers = num_layers,
                batch_first = True,
                dropout = 0.3
            )

            self.fc = nn.Linear(hiddeen_size,num_classes)
    def forward(self,x):
        x = x.squeeze(1)
        h0 = torch.zeros(self.num_layers,x.size(0),self.hidden_size).to(x.device)
        out, _ = self.gru(x, h0)
        out     = out[:, -1, :]     # last step!
        out     = self.fc(out)
        return out

# %%
import torch 
import torch.nn as nn

class GRU_classifier(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, num_classes):
        super().__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        
        self.gru = nn.GRU(
            input_size=input_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            batch_first=True,  # Added comma
            dropout=0.3 if num_layers > 1 else 0 # Dropout only works if num_layers > 1
        )

        self.fc = nn.Linear(hidden_size, num_classes)

    def forward(self, x):
        # Ensure x is (batch, seq_len, input_size)
        # x = x.squeeze(1) # Only keep if your input has an extra dim at index 1
        
        # Initialize hidden state
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        
        # Forward propagate GRU
        out, _ = self.gru(x, h0)
        
        # Decode the hidden state of the last time step
        out = out[:, -1, :] 
        out = self.fc(out)
        return out
